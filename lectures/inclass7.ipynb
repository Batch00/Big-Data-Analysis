# %%
import pandas as pd
df = pd.read_excel("../data/inclass_7_homes.xls")

# %%
df
# Out:
#           FID  OBJECTID     PARCELNO CurrentPar                         Owner  \
# 0       11048     50599  70801182002     Active            MIDDLETON, CITY OF
# 1       11049     50600  70801187504     Active            MIDDLETON, CITY OF
# 2       11052     50603  70801185006     Active            MIDDLETON, CITY OF
# 3       11053     50604  70801190509     Active            MIDDLETON, CITY OF
# 4       11054     50605  70801192507     Active            MIDDLETON, CITY OF
# ...       ...       ...          ...        ...                           ...
# 25022  202123    323711  70923321015     Active  BAYVIEW HOUSING PARTNERS LLC
# 25023  202124    323712  70923321015     Active  BAYVIEW HOUSING PARTNERS LLC
# 25024  202125    323713  70923321015     Active  BAYVIEW HOUSING PARTNERS LLC
# 25025  202126    323714  70923321015     Active  BAYVIEW HOUSING PARTNERS LLC
# 25026  202127    323715  70923321015     Active  BAYVIEW HOUSING PARTNERS LLC
#
# ...

# %%
df["priceperac"].sum()
# Out:
# 20373394026.84602
